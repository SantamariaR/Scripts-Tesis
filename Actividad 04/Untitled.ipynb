# %% [markdown]
# # Actividad 4

# %%
import pandas as pd

# %%
df = pd.read_csv('Aperturas_RefL0100N1504_snap_28_aperture_30.dat')

# %%
df.head(80)
# Out:
#     GalaxyID         GroupID  SnapNum      Redshift  SubGroupNumber  \
# 0    9498012  28000000000002       28  2.220446e-16               6
# 1    9508202  28000000000002       28  2.220446e-16               7
# 2    9512113  28000000000002       28  2.220446e-16               8
# 3    9517736  28000000000002       28  2.220446e-16               9
# 4    9519365  28000000000002       28  2.220446e-16              10
# ..       ...             ...      ...           ...             ...
# 75  59447030  28000000002588       28  2.220446e-16               1
# 76  10883094  28000000002601       28  2.220446e-16               0
# 77  10883983  28000000002602       28  2.220446e-16               0
# 78  10910419  28000000002638       28  2.220446e-16               0
# 79   3169927  28000000002638       28  2.220446e-16               1
#
#     CentreOfPotential_x  CentreOfPotential_y  CentreOfPotential_z  \
# 0              8.913222            35.828056            54.839039
# ...

# %%
df.describe()
# Out:
#            GalaxyID       GroupID  SnapNum      Redshift  SubGroupNumber  \
# count  1.330000e+04  1.330000e+04  13300.0  1.330000e+04    13300.000000
# mean   1.157440e+07  2.800001e+13     28.0  2.220446e-16       14.467143
# std    1.166503e+07  3.486025e+07      0.0  0.000000e+00       49.958821
# min    1.000000e+00  2.800000e+13     28.0  2.220446e-16        0.000000
# 25%    4.494468e+06  2.800000e+13     28.0  2.220446e-16        0.000000
# 50%    1.061103e+07  2.800000e+13     28.0  2.220446e-16        0.000000
# 75%    1.283367e+07  2.800000e+13     28.0  2.220446e-16        4.000000
# max    6.593720e+07  2.800090e+13     28.0  2.220446e-16      763.000000
#
#        CentreOfPotential_x  CentreOfPotential_y  CentreOfPotential_z  \
# count         13300.000000         13300.000000         13300.000000
# mean             51.454312            52.331232            48.459022
# std              29.236947            28.430540            26.818288
# ...

# %%
df['Stars_Mass']-max(df['Stars_Mass'])
# Out:
# 0       -1.751554e+12
# 1       -1.829384e+12
# 2       -1.770912e+12
# 3       -1.883095e+12
# 4       -1.857092e+12
#              ...
# 13295   -1.903035e+12
# 13296   -1.904145e+12
# 13297   -1.903793e+12
# 13298   -1.902575e+12
# 13299   -1.904416e+12
# Name: Stars_Mass, Length: 13300, dtype: float64

# %%
mask = (df['GroupID']==28000000000001)
df_1 = df['Stars_Mass'][mask]
df_1
# Out:
# 2553    2.704106e+10
# 2554    3.856083e+10
# 2555    4.573218e+10
# 2556    1.980979e+10
# 2557    2.073764e+10
#             ...
# 5645    2.798827e+10
# 5646    3.440095e+10
# 5647    2.449730e+10
# 5648    3.793732e+10
# 5649    2.433223e+10
# Name: Stars_Mass, Length: 297, dtype: float64
