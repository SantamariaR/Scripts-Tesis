# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

# %%
DF = pd.read_csv('galaxy_massive_project_RefL0100N1504_snap_28.dat')

# %%
DF
# Out:
#       GalaxyID  SnapNum         GroupID    Stars_Mass  SF_Hydrogen  SF_Oxygen  \
# 0      2425266       28  28000000000385  1.939876e+10     0.630953   0.020944
# 1      6659446       28  28000000000025  1.154251e+10     0.676607   0.015338
# 2      8670584       28  28000000000822  1.352261e+10     0.656548   0.017297
# 3      8727293       28  28000000000977  2.235380e+10     0.703474   0.008600
# 4      8785846       28  28000000001052  1.044520e+10     0.690803   0.011504
# ...        ...      ...             ...           ...          ...        ...
# 3088  18419292       28  28000000001032  3.084745e+10     0.670421   0.014992
# 3089  18719249       28  28000000000024  3.194702e+11     0.714975   0.007912
# 3090  19507560       28  28000000000054  1.853264e+11     0.666798   0.016656
# 3091  20242621       28  28000000000084  2.609417e+11     0.671778   0.014907
# 3092  20782068       28  28000000000123  1.847714e+11     0.727761   0.005662
#
# ...

# %%
DF.describe()
# Out:
#            GalaxyID  SnapNum       GroupID    Stars_Mass  SF_Hydrogen  \
# count  3.093000e+03   3093.0  3.093000e+03  3.093000e+03  3093.000000
# mean   1.224438e+07     28.0  2.800000e+13  4.931989e+10     0.664074
# std    4.193485e+06      0.0  1.798118e+06  9.590823e+10     0.036542
# min    3.236600e+04     28.0  2.800000e+13  1.000544e+10     0.479362
# 25%    9.297858e+06     28.0  2.800000e+13  1.490940e+10     0.649371
# 50%    1.075258e+07     28.0  2.800000e+13  2.406874e+10     0.671119
# 75%    1.619177e+07     28.0  2.800000e+13  4.822028e+10     0.687775
# max    2.198636e+07     28.0  2.800010e+13  1.905425e+12     0.750344
#
#          SF_Oxygen       SF_Mass      NSF_Mass  BlackHoleMass  \
# count  3093.000000  3.093000e+03  3.093000e+03   3.093000e+03
# mean      0.016073  2.761454e+09  3.391539e+11   6.285562e+07
# std       0.005674  3.036835e+09  2.253858e+12   2.011803e+08
# min       0.000578  1.924818e+06  0.000000e+00   1.566259e+05
# ...

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3093 entries, 0 to 3092
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GalaxyID           3093 non-null   int64
#  1   SnapNum            3093 non-null   int64
#  2   GroupID            3093 non-null   int64
#  3   Stars_Mass         3093 non-null   float64
#  4   SF_Hydrogen        3093 non-null   float64
#  5   SF_Oxygen          3093 non-null   float64
#  6   SF_Mass            3093 non-null   float64
#  7   NSF_Mass           3093 non-null   float64
#  8   BlackHoleMass      3093 non-null   float64
#  9   StarFormationRate  3093 non-null   float64
#  10  KappaCoRot         3093 non-null   float64
# dtypes: float64(8), int64(3)
# memory usage: 265.9 KB

# %%
DF.keys()
# Out:
# Index(['GalaxyID', 'SnapNum', 'GroupID', 'Stars_Mass', 'SF_Hydrogen',
#        'SF_Oxygen', 'SF_Mass', 'NSF_Mass', 'BlackHoleMass',
#        'StarFormationRate', 'KappaCoRot'],
#       dtype='object')

# %%
DF_NEW = DF.copy()

# %%
x = DF_NEW.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
DF_NEW_1 = pd.DataFrame(x_scaled,columns =['Stars_Mass', 'SF_Hydrogen','SF_Oxygen', 'SF_Mass', 'NSF_Mass', 'BlackHoleMass','StarFormationRate', 'KappaCoRot'])

# %%
DF_NEW.hist(edgecolor='black',bins = 20 ,linewidth=0.2)
fig=plt.gcf()
fig.set_size_inches(15,15)
plt.show()

# %%
X = DF_NEW.iloc[:,:]
f, ax = plt.subplots(figsize=(10, 8))
corr_1 = X.corr()
print(corr_1)
sns.heatmap(corr_1, mask=np.zeros_like(corr_1), 
          cmap=sns.diverging_palette(220, 10, as_cmap=True),square=True, ax=ax, linewidths=.5)
plt.show()
# Out:
#                    Stars_Mass  SF_Hydrogen  SF_Oxygen   SF_Mass  NSF_Mass  \
# Stars_Mass           1.000000     0.160808  -0.138318  0.542163  0.892178
# SF_Hydrogen          0.160808     1.000000  -0.993194  0.192184  0.112351
# SF_Oxygen           -0.138318    -0.993194   1.000000 -0.154923 -0.096577
# SF_Mass              0.542163     0.192184  -0.154923  1.000000  0.541359
# NSF_Mass             0.892178     0.112351  -0.096577  0.541359  1.000000
# BlackHoleMass        0.857166     0.199891  -0.181098  0.357129  0.727000
# StarFormationRate    0.590074     0.110171  -0.079141  0.895187  0.572614
# KappaCoRot          -0.253596    -0.356079   0.361935  0.181061 -0.165048
#
#                    BlackHoleMass  StarFormationRate  KappaCoRot
# Stars_Mass              0.857166           0.590074   -0.253596
# SF_Hydrogen             0.199891           0.110171   -0.356079
# SF_Oxygen              -0.181098          -0.079141    0.361935
# ...

# %%
DF_NEW['Log(Sm)']    = np.log10(DF['Stars_Mass'])
DF_NEW['Log(BHM)']   = np.log10(DF['BlackHoleMass'])
DF_NEW['Log(sSFR)']  = np.log10(DF['StarFormationRate']) - np.log10(DF['Stars_Mass'])
DF_NEW['12+Log(O/H)']=  12 + np.log10(DF['SF_Oxygen'])-np.log10(DF['SF_Hydrogen'])-np.log10(16)
DF_NEW['F_g']        = DF['SF_Mass']/(DF['Stars_Mass']+DF['SF_Mass'])

# %%
DF_NEW.drop(columns = ['SF_Hydrogen','SF_Oxygen', 'SF_Mass', 'NSF_Mass', 'BlackHoleMass',
       'StarFormationRate','Stars_Mass'], inplace = True)

# %%
DF_NEW
# Out:
#       GalaxyID  SnapNum         GroupID  KappaCoRot    Log(Sm)  Log(BHM)  \
# 0      2425266       28  28000000000385    0.601997  10.287774  6.336787
# 1      6659446       28  28000000000025    0.243161  10.062300  8.488903
# 2      8670584       28  28000000000822    0.615248  10.131061  5.951105
# 3      8727293       28  28000000000977    0.175432  10.349351  7.189065
# 4      8785846       28  28000000001052    0.335223  10.018917  6.792303
# ...        ...      ...             ...         ...        ...       ...
# 3088  18419292       28  28000000001032    0.512549  10.489219  7.410648
# 3089  18719249       28  28000000000024    0.301624  11.504430  8.816474
# 3090  19507560       28  28000000000054    0.334936  11.267937  8.560718
# 3091  20242621       28  28000000000084    0.365459  11.416543  8.593541
# 3092  20782068       28  28000000000123    0.158204  11.266635  8.577237
#
#       Log(sSFR)  12+Log(O/H)       F_g
# 0    -10.350629     9.316936  0.058125
# ...

# %%
X = DF_NEW.iloc[:,3:]
f, ax = plt.subplots(figsize=(10, 8))
corr_1 = X.corr()
print(corr_1)
sns.heatmap(corr_1, mask=np.zeros_like(corr_1), 
          cmap=sns.diverging_palette(220, 10, as_cmap=True),square=True, ax=ax, linewidths=.5)
plt.show()
# Out:
#              KappaCoRot   Log(Sm)  Log(BHM)  Log(sSFR)  12+Log(O/H)       F_g
# KappaCoRot     1.000000 -0.272389 -0.503542   0.456713     0.395308  0.451864
# Log(Sm)       -0.272389  1.000000  0.848470  -0.380265    -0.182142 -0.420524
# Log(BHM)      -0.503542  0.848470  1.000000  -0.522852    -0.365360 -0.527589
# Log(sSFR)      0.456713 -0.380265 -0.522852   1.000000     0.164372  0.792240
# 12+Log(O/H)    0.395308 -0.182142 -0.365360   0.164372     1.000000 -0.138781
# F_g            0.451864 -0.420524 -0.527589   0.792240    -0.138781  1.000000
