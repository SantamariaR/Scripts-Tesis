# %% [markdown]
# ## Todos los scrip que use para el proyecto de altas masas

# %% [markdown]
# La tabla de merger está calculada pra las galaxias que cumplan las condiciones:
# SF_Oxygen > 0
# SF_Hydrogen > 0
# SubGroupNumber = 0
# log10(SF_Mass) >= 7.75
# 10.6<=log10(Stars_Mass)<= 10.8
# Kappaco<=0.56 o Kappaco>=0.3
#
# Falta cambiar la appertura de las magnitudes a 30kpc

# %%
import pandas as pd
import numpy as np

# %%
table_merger = pd.read_csv('/home/ramiro/Facultad/Tesis/Datos/Proyecto Altas Masas/Merger_history_altas_masas.dat')

# %%
table_magni  = pd.read_csv('/home/ramiro/Facultad/Tesis/Datos/Proyecto Altas Masas/bin_proyecto_altas_masas_106_108.dat')

# %%
table_merger
# Out:
#      GalaxyID_test    GroupID_test  Lm_snap1  Lm_snap2  Lm_snap3  Lm_snap4  \
# 0         14674760  28000000000186       NaN       NaN       NaN       NaN
# 1         15595158  28000000000294       NaN       1.0       1.0  1.000000
# 2         15350630  28000000000256       NaN       NaN       NaN       NaN
# 3         15207474  28000000000236       NaN       NaN       NaN       NaN
# 4         15611795  28000000000297       NaN       NaN       NaN       NaN
# ..             ...             ...       ...       ...       ...       ...
# 157       17277488  28000000000609       NaN       NaN       1.0  1.000000
# 158       17374402  28000000000644       NaN       1.0       1.0  1.514814
# 159       17654556  28000000000719       NaN       1.0       1.0  1.000000
# 160       17715888  28000000000744       NaN       1.0       1.0  1.000000
# 161       18165555  28000000000914       NaN       NaN       NaN       NaN
#
# ...

# %%
mask = (table_magni['KappaCoRot']<=0.3)

# %%
def porcentaje_merger(lm):
        if x<lm:
            y = 0
        else:
            y=1
            
        return y

# %%
table_merger.apply(porcentaje_merger(1.1),axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-7cad30f674ae> in <module>
# ----> 1 table_merger.apply(porcentaje_merger(x,1.1),axis = 1)
#
# NameError: name 'x' is not defined

# %%
table_merger.keys()
# Out:
# Index(['GalaxyID_test', 'GroupID_test', 'Lm_snap1', 'Lm_snap2', 'Lm_snap3',
#        'Lm_snap4', 'Lm_snap5', 'Lm_snap6', 'Lm_snap7', 'Lm_snap8', 'Lm_snap9',
#        'Lm_snap10', 'Lm_snap11', 'Lm_snap12', 'Lm_snap13', 'Lm_snap14',
#        'Lm_snap15', 'Lm_snap16', 'Lm_snap17', 'Lm_snap18', 'Lm_snap19',
#        'Lm_snap20', 'Lm_snap21', 'Lm_snap22', 'Lm_snap23', 'Lm_snap24',
#        'Lm_snap25', 'Lm_snap26', 'Lm_snap27', 'Lm_snap28'],
#       dtype='object')

# %%
a = 200
b = 33
if b > a:
    print("b is greater than a")
else:
    print("b is not greater than a")
# Out:
# b is not greater than a
